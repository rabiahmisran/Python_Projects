# %%
# In Python, both modules and packages organize and structure the code.

# In simple terms, a module is a single file containing Python code, whereas a 

# package is a collection of modules that are organized in a directory hierarchy.
 
# What is a Module in Python?

# In Python, a module is a single file containing Python definitions and statements. 

# These definitions and statements can include variables, functions, and classes 

# and can be used to organize related functionality into a single, reusable package.

# Module organizes and reuses code in Python by grouping related code into a single file.
 
# Modules can be imported and used in other Python files using the import statement.
 
# Some popular modules in Python are math, random, csv, and datetime.
 
# What is a Package in Python?

# Python Packages are collections of modules that provide a set of related functionalities, 

# and these modules are organized in a directory hierarchy. 

# In simple terms, packages in Python are a way of organizing related modules in a single namespace.
 
# Packages in Python are installed using a package manager like pip 

# (a tool for installing and managing Python packages).

# Each Python package must contain a file named _init_.py. 

# _init_ file may be empty.

# This file contains the initialization code for the corresponding package.

# Some popular Python packages are: NumPy, Pandas, and Matplotlib.

# %%
import mymodule
num = 89
mymodule.checkEvenOdd(num)
# Out:
# Odd Number

# %%
# check whether string is palindrome or not
str1 = 'madam'
if str1==mymodule.stringReverse(str1):
    print('Palindrome')
else:
    print('Not A Palindrome')

# %%
import mymodule as mm
num = 24
mm.checkEvenOdd(num)
# Out:
# Even Number

# %%
# Using a Package

from mypackage import addition

res = addition.add(10,20)
print(res)

res = addition.multiply(10,20)
print(res)

res = addition.divide(10,20)
print(res)
# Out:
# 30
# 200
# 0.5

# %%
from mypackage import strings

print(strings.strReverse('Python'))
# Out:
# nohtyP

# %%
# another syntax for Using a Package

from mypackage import addition , strings

res = addition.multiply(10,20)
print(res)

print(strings.strReverse('Python'))
# Out:
# 200
# nohtyP

# %%
# another syntax for Using a Package
# if you wish to use a dedicated function only

from mypackage.addition import multiply

res = multiply(10,20)
print(res)
# Out:
# 200
