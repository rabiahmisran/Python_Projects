# %%
# What is an API?
# API stands for Application Programming Interface.
 
# Think of it like a waiter in a restaurant:
# You (the user) tell the waiter what you want (e.g., a burger).
# The waiter takes your request to the kitchen (the system).
# The kitchen prepares the food and gives it to the waiter.
# The waiter brings it back to you.
 
# In tech terms:
# You (the app or user) send a request using the API.
# The API talks to a server or system.
# The system sends back the data.
# You get the result in your app.
 
'''
Benefits of Using APIs
 
Saves Time
You don’t need to build everything from scratch. Use APIs to access services others already built.
 
Enables Integration
APIs let different apps or systems "talk" to each other. For example, your weather app gets data from a weather API.
 
Real-time Access
APIs let apps fetch live or updated data instantly (like traffic updates or prices).
 
Secure and Controlled
APIs allow access to data without exposing everything—you only get what the provider allows.
 
Scalable and Flexible
You can add more features easily by using more APIs.
'''
 
'''
Examples
1. Grab (Ride-hailing & Delivery App)
 
Grab uses many APIs to function. For example:
 
Google Maps API – to show maps, routes, and real-time traffic.
 
Payment APIs – for cashless payments.
 
Notification APIs – to send messages to your phone about your driver or order.
 
Location APIs – to find where you are and where to go.
 
 
Example: When you book a Grab ride:
 
The app uses location APIs to detect your pickup point.
 
Then it uses Google Maps API to calculate distance and route.
 
It might use pricing APIs to calculate your fare.
 
Finally, it uses notification APIs to update you when your ride is near.
'''
 
# "APIs are like pre-written functions or services provided by other software or companies,
# available over the internet, that you can use in your own apps."
 
# An API is a bridge that connects two different software systems so
# they can talk to each other and share information.
# Out:
# '\nExamples\n1. Grab (Ride-hailing & Delivery App)\n\nGrab uses many APIs to function. For example:\n\nGoogle Maps API – to show maps, routes, and real-time traffic.\n\nPayment APIs – for cashless payments.\n\nNotification APIs – to send messages to your phone about your driver or order.\n\nLocation APIs – to find where you are and where to go.\n\n\nExample: When you book a Grab ride:\n\nThe app uses location APIs to detect your pickup point.\n\nThen it uses Google Maps API to calculate distance and route.\n\nIt might use pricing APIs to calculate your fare.\n\nFinally, it uses notification APIs to update you when your ride is near.\n'

# %%
# Install wolframalpha
# Wolframalpha API
# !pip install wolframalpha==3.0.0
# Out:
# Requirement already satisfied: wolframalpha==3.0.0 in c:\users\user\anaconda3\lib\site-packages (3.0)
# Requirement already satisfied: jaraco.itertools>=2.0 in c:\users\user\anaconda3\lib\site-packages (from wolframalpha==3.0.0) (6.4.3)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from wolframalpha==3.0.0) (1.17.0)
# Requirement already satisfied: xmltodict in c:\users\user\anaconda3\lib\site-packages (from wolframalpha==3.0.0) (1.0.4)
# Requirement already satisfied: more_itertools>=4.0.0 in c:\users\user\anaconda3\lib\site-packages (from jaraco.itertools>=2.0->wolframalpha==3.0.0) (10.8.0)
# Requirement already satisfied: inflect in c:\users\user\anaconda3\lib\site-packages (from jaraco.itertools>=2.0->wolframalpha==3.0.0) (7.5.0)
# Requirement already satisfied: typeguard>=4.0.1 in c:\users\user\anaconda3\lib\site-packages (from inflect->jaraco.itertools>=2.0->wolframalpha==3.0.0) (4.5.1)
# Requirement already satisfied: typing_extensions>=4.14.0 in c:\users\user\anaconda3\lib\site-packages (from typeguard>=4.0.1->inflect->jaraco.itertools>=2.0->wolframalpha==3.0.0) (4.15.0)

# %%
import wolframalpha
client = wolframalpha.Client('QYHEU6RJ5W')

# %%
res = client.query('temperature in kuala lumpur')
res
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\anaconda3\Lib\urllib\request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File ~\anaconda3\Lib\http\client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1383     body = _encode(body, 'body')
# -> 1384 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1333, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1332     raise CannotSendHeader()
# -> 1333 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1093, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1092 del self._buffer[:]
# -> 1093 self.send(msg)
#    1095 if message_body is not None:
#    1096
#    1097     # create a consistent interface to message_body
#
# File ~\anaconda3\Lib\http\client.py:1037, in HTTPConnection.send(self, data)
#    1036 if self.auto_open:
# -> 1037     self.connect()
#    1038 else:
#
# File ~\anaconda3\Lib\http\client.py:1479, in HTTPSConnection.connect(self)
#    1477     server_hostname = self.host
# -> 1479 self.sock = self._context.wrap_socket(self.sock,
#    1480                                       server_hostname=server_hostname)
#
# File ~\anaconda3\Lib\ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File ~\anaconda3\Lib\ssl.py:1076, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1075                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1076             self.do_handshake()
#    1077 except:
#
# File ~\anaconda3\Lib\ssl.py:1372, in SSLSocket.do_handshake(self, block)
#    1371         self.settimeout(None)
# -> 1372     self._sslobj.do_handshake()
#    1373 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1032)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 res = client.query('temperature in kuala lumpur')
#       2 res
#
# File ~\anaconda3\Lib\site-packages\wolframalpha\__init__.py:53, in Client.query(self, input, params, **kwargs)
#      51 query = urllib.parse.urlencode(tuple(data))
#      52 url = 'https://api.wolframalpha.com/v2/query?' + query
# ---> 53 resp = urllib.request.urlopen(url)
#      54 assert resp.headers.get_content_type() == 'text/xml'
#      55 assert resp.headers.get_param('charset') == 'utf-8'
#
# File ~\anaconda3\Lib\urllib\request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File ~\anaconda3\Lib\urllib\request.py:489, in OpenerDirector.open(self, fullurl, data, timeout)
#     486     req = meth(req)
#     488 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 489 response = self._open(req, data)
#     491 # post-process response
#     492 meth_name = protocol+"_response"
#
# File ~\anaconda3\Lib\urllib\request.py:506, in OpenerDirector._open(self, req, data)
#     503     return result
#     505 protocol = req.type
# --> 506 result = self._call_chain(self.handle_open, protocol, protocol +
#     507                           '_open', req)
#     508 if result:
#     509     return result
#
# File ~\anaconda3\Lib\urllib\request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File ~\anaconda3\Lib\urllib\request.py:1367, in HTTPSHandler.https_open(self, req)
#    1366 def https_open(self, req):
# -> 1367     return self.do_open(http.client.HTTPSConnection, req,
#    1368                         context=self._context)
#
# File ~\anaconda3\Lib\urllib\request.py:1322, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1319         h.request(req.get_method(), req.selector, req.data, headers,
#    1320                   encode_chunked=req.has_header('Transfer-encoding'))
#    1321     except OSError as err: # timeout error
# -> 1322         raise URLError(err)
#    1323     r = h.getresponse()
#    1324 except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1032)>
