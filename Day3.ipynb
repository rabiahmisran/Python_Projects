# %%
# TYPE CASTING
# IT'S A PROCESS OF CONVERTING ONE DATA TYPE TO ANOTHER DATA TYPE

# automatic type conversion   IMPLICIT
# lower data type will be converted to higher data type automatically

a = 10
b = 45.03
res = a + b     # 10.00 + 45.03
print(res)
# Out:
# 55.03

# %%
# manual type conversion    EXPLICIT
# performed by developers


a = 10
b = 45.03
res = a + int(b)
print(res)

# we have a floatVar which needs to be converted into intVar
#  int(floatvar)      int(23.33) --> 23

# we have an intVar which needs to be converted into floatVar
#  float(intVar)     float(10)  --> 10.0

# we have a intVar which needs to be converted into strVar
#  str(intVar)         str(24)   --> '24'

# we have a floatVar which needs to be converted into strVar
#  str(floatVar)         str(24.334)   --> '24.334'

# converting bool into int and float

choice = True
print(int(choice))
print(float(choice))

choice = False
print(int(choice))
print(float(choice))

print(bool(res))
print(str(choice))

name = '786'
print(int(name))
# Out:
# 55
# 1
# 1.0
# 0
# 0.0
# True
# False
# 786

# %%
# TAKING AN USER INPUT

# input()
# is a built-in function used to take input from the user
# input(prompt/message)

name = input('Enter Your Name :')
print('Apa nama awak?',name)

name = input('Enter Your Name :')
print('Welcome User',name)
# Out:
# Enter Your Name :aqil
# Apa nama awak? aqil
# Enter Your Name :aqil
# Welcome User aqil

# %%
print('Enter Your City')
city = input()
print('tempat tinggal saya' ,city)

city = input()
print('where is your city', city)
# Out:
# Enter Your City
# tempat tinggal saya beranang

# %%
# Input() function will get the value in a form of STRING

val1 = input('Enter The First Value : ')
val2 = input('Enter The First Value : ')
res = val1 + val2
print(f'After Addition {val2} + {val2} Result Will Be {res}')
# Out:
# Enter The First Value : 20
# Enter The First Value : 26
# After Addition 26 + 26 Result Will Be 2026

# %%
val1 = int(input('Enter The First Value : '))   # 20
val2 = int(input('Enter The First Value : '))  # 26
res = val1 + val2                          # res = 20+26
print(f'After Addition {val2} + {val2} Result Will Be {res}')
# Out:
# Enter The First Value : 20
# Enter The First Value : 26
# After Addition 26 + 26 Result Will Be 46

# %%
name = input('Enter Your Name:')
weight = float(input('Enter Your Weight in kg:'))
height = float(input('Enter Your Height in cm:'))
h_m = height/100
bmi = weight/(h_m*h_m)
print(f'Hi {name}, Your BMI is {bmi:2f}😍')
# Out:
# Enter Your Name:auni
# Hi auni
# Enter Your Weight in kg:56
# Enter Your Height in cm:58
# Hi auni, Your BMI is 166.468490😍

# %%
name = input('Hi, Enter Your Name: ')
weight = float(input('Enter Your Weight in kg: '))
height = float(input('Enter Your Height in cm: '))

h_m = height/100

bmi = weight /(h_m*h_m)
print(f'Hi {name}, Your BMI is {bmi:2f}😍')
# Out:
# Hi, Enter Your Name: a
# Enter Your Weight in kg: 50
# Enter Your Height in cm: 160
# Hi a, Your BMI is 19.531250😍

# %%
# Operators
# Operators are used to perform operations on variables

# a.) ARITHEMATIC OPERATORS
# ARE USED TO PERFORM MATHEMATICAL OPERATIONS ON VARIABLES
# + - * / // **

print(10+5)
print(10-5)
print(10*5)
print(10/5)    #IN PHYTON DIVISION OPERATOR / USED TO RETURN VALUE IN FLOAT
print(10//5)   #IN PHYTON FLOOR DIVISION OPERATOR // USED TO RETURN VALUE IN INTEGER
print(10**5)   # modulus used to give reminder
print(2**8)    # 2 raise to the power of 8   ** Exponent
print(72*72)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 100000
# 256
# 5184

# %%
# b.) ASSIGNMENT OPERATORS
# used to assign a value to a variable

a = 90   # a as 90  or  a is 90
print(a)
# Out:
# 90

# %%
# c.) COMPARISON OPERATORS
# < >  ==  !=  <=   >=
# USED TO RETURN A BOOLEAN VALUE [True / False]

print(10<5)
print(10>5)
print(98==98)
print(100!=1000)
print(100!=100)

age = 18
print(age>=18)  #age should be equal to 18 or age should be greater than 18


# marks <= 100
# Out:
# False
# True
# True
# True
# False
# True

# %%
# d.) LOGICAL OPERATORS
#  works with multiple conditions
#  and  or  not
#  USED TO RETURN A BOOLEAN VALUE  [True / False]

# and
# and requires more than one condition
# and will return TRUE when both or all the conditions are TRUE

print(100== and 200==200 and 300=300)
#    True     True    True

print(100==100 and 20==2000)
#    True   False

# %%
# or
# or requires more than one condition
# or will return TRUE when both or all the conditions are TRUE
# or will also returns True if atleast any condition is TRUE
# or will return FALSE when both or all the conditions are FALSE

print(100== or 200==200 or 300==300)
#   True  True   True

print(100==100 or 200==200)
#   True   False

print(100==1000 or 200==2000)
#   False   False

# %%
# not
# used to reverse the result

print(not(100==100 and 200==200))
# Out:
# False

# %%
# e.) Membership Operators
#    in  not  in

# in
# used to return True
# if the specified value exists in a Sequence

print('P' in 'Phyton')
print('o' in 'Phyton')
print('John' in ['John','Smith','Alex'])
print('x' in 'Python')
print('p' in 'Python')
# Out:
# True
# True
# True
# False
# False

# %%
# not in
print('x' in 'Python')
print('x' not in 'Python')

# hey interpreter I think that this x does not exist in Python  ??
# yes you are Right

print('t' not in 'Phyton')
# hey interpreter I think that this t does not exist in Phyton
# no you are wrong
# Out:
# False
# True
# False
